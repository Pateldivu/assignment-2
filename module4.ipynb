# %% [markdown]
# 1)What is File function in python? What is keywords to create and write file.
#
# ANS)Python file object provides methods and attributes to access and manipulate files. Using file objects, we can read or write any files. Whenever we open a file to perform any operations on it, Python returns a file object. To create a file object in Python use the built-in functions, such as open() and os.

# %%
#2)Write a Python program to read an entire text file.

file_object = open("myfile.txt","w")
file_object.write("hello,this is file handling")
file_object.close()
file_object = open("myfile.txt","r")
print(file_object.readlines())
# Out:
# ['hello,this is file handling']

# %%
#3)Write a Python program to append text to a file and display the text.

file_object = open("file.txt","w")
file_object.write("I am Divya \n")
file_object.close()
file_object = open("file.txt","a")
file_object.write("I am girl")
file_object.close()
file_object = open("file.txt","r")
print(file_object.read())
# Out:
# I am Divya
# I am girl

# %%
#4)Write a Python program to read first n lines of a file.

file_object = open("file.txt","w")
file_object.write("I am Divya. \n I am girl")
file_object.close()
file_object = open("file.txt","r")
file_object.readline()
# Out:
# 'I am Divya. \n'

# %%
#5)Write a Python program to read last n lines of a file.
file_object = open("file.txt","w")
file_object.write("I am Divya. \n I am girl.")
file_object.close()
file_object = open("file.txt","r")
file_object.readline()[-10::]
# Out:
# 'm Divya. \n'

# %%
#6)Write a Python program to read a file line by line and store it into a list

file_object = open("file.txt","w")
file_object.writelines("abc\n def \ngfi")
file_object.close()
file_object = open("file.txt","r")
data=file_object.read()
print(data)
data1 = []

for i in data:
  data1 += i
print(data1)
# Out:
# abc
#  def
# gfi
# ['a', 'b', 'c', '\n', ' ', 'd', 'e', 'f', ' ', '\n', 'g', 'f', 'i']

# %%
#7)Write a Python program to read a file line by line store it into a variable.
file_object = open("file.txt","w")
file_object.writelines("hello \neveryone \nwelcome \nto \ntops")
file_object.close()
file_object = open("file.txt","r")
data=file_object.read()
print(data)

var = ''
for i in data:
  var +=i

var
# Out:
# hello
# everyone
# welcome
# to
# tops
# 'hello \neveryone \nwelcome \nto \ntops'

# %%
#8)Write a python program to find the longest words.

# %%
#9)Write a Python program to count the number of lines in a text file.

file_object = open("file.txt","w")
file_object.writelines("hello \neveryone \nwelcome \nto \ntops")
file_object.close()
file_object = open("file.txt","r")
data=file_object.readlines()
print(data)
count = len(data)
print(count)
# Out:
# ['hello \n', 'everyone \n', 'welcome \n', 'to \n', 'tops']
# 5

# %%
#10)Write a Python program to count the frequency of words in a file.

file_object = open("file.txt","w")
file_object.writelines("hello")
file_object.close()
file_object = open("file.txt","r")
data=file_object.read()
data1 = data.count('l')
print(data1)
# Out:
# 2

# %%
#11)Write a Python program to write a list to a file.
list = ['hello', 'everyone', 'welcome', 'to', 'tops']
textfile = open("file.txt","w")
textfile.writelines(i)
textfile.close()
for i in list:
  print(i)
# Out:
# hello
# everyone
# welcome
# to
# tops

# %%
#12)Write a Python program to copy the contents of a file to another file.

file_object = open("file.txt","w")
file_object.write("hello everyone")
file_object.close()
file_object = open("file.txt","r")
data=file_object.readlines()
data1=file_object.readlines()
for i in data:
  for data in data1: 
print(data1)
# Out:
#   File "<ipython-input-24-22be9339c88a>", line 11
#     print(data1)
#                 ^
# IndentationError: expected an indented block

# %% [markdown]
# 13)Explain Exception handling? What is an Error in Python?
#
# ANS)An exception can be defined as an unusual condition in a program resulting in the interruption in the flow of the program. Whenever an exception occurs, the program stops the execution, and thus the further code is not executed. Therefore, an exception is the run-time errors that are unable to handle to Python script.

# %% [markdown]
# 14)How many except statements can a try-except block have? Name Some built-in exception classes:
#
# ANS)Try except have to be at least one except statement.
#
# Built-in exception classes:
# > AssertionError - Raised when assert statement fails.
# >AttributeError - Raised when attribute assignment or reference fails.
# >EOFError - Raised when the input() functions hits end-of-file condition.
# >FloatingPointError - Raised when a floating point operation fails.
# >GeneratorExit - Raise when a generator's close() method is called.
# >ImportError - Raised when the imported module is not found

# %% [markdown]
# 15)When will the else part of try-except-else be executed?
#
# ANS) The else part is executed when no exception occurs.

# %% [markdown]
# 16)Can one block of except statements handle multiple exception?
#
# ANS)yes, like except TypeError, SyntaxError [,. . . ]
# Each type of exception can be specified directly. There is no need to put it in a list

# %% [markdown]
# 17)When is the finally block executed?
#
# ANS)The finally block always executes when the try block exits. This ensures that the finally block is executed even if an unexpected exception occurs.

# %% [markdown]
# 18)What happens when „1‟== 1 is executed?
#
# ANS)It simply evaluates to false and does not raise any exception.

# %% [markdown]
# 19)How Do You Handle Exceptions With Try/Except/Finally In Python? Explain with coding snippets.
#
# ANS)Try: This block will test the excepted error to occur.
#
# Except: Here you can handle the error.
#
# Else: If there is no exception then this block will be executed.
#
# Finally: Finally block always gets executed either exception is generated or not.
#
# coding:
#
# print('hello')
#
# try:
#   age = int(input('enter your age: '))
#   print(age)
#
# except ValueError as err:
#   print('--error--', err)
#
# finally:
#   print('always run')
#
# print('world')

# %%
#20)Write python program that user to enter only odd numbers, else will raise an exception.

try:
  number = int(input("enter your number: "))
  mod = number % 2
  if mod > 0:
    print ("number is odd")
  else:
    print("number is even")
except Exception as err:
  print('error', err)
# Out:
# enter your number: 3
# number is odd

# %% [markdown]
# 21)What are oops concepts? Is multiple inheritance supported in java

# %% [markdown]
# 22)How to Define a Class in Python? What Is Self? Give An Example Of A Python Class.
#
# ANS)class: A class is a user-defined blueprint or prototype from which objects are created. Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances of that type to be made.
#
# Self:self represents the instance of the class. By using the “self” we can access the attributes and methods of the class in python. It binds the attributes with the given arguments. The reason you need to use self. is because Python does not use the @ syntax to refer to instance attributes

# %%
#23)Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle

class Rectangle():   
  def __init__(self, l, w):
    self.length = l
    self.width = w
    
  def Rectangle_are(self):
    return self.length * self.width

newRectangle = Rectangle(10,12)
print(newRectangle.Rectangle_are())
# Out:
# 120

# %%
#24)Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle

class Circle():
  def __init__(self, r):
    self.radius = r
  
  def area(self):
     return (self.radius**2*3.14)

  def perimeter(self):
     return (self.radius*2*3.14)

newCircle=Circle(5)
print(newCircle.area())
print(newCircle.perimeter())
# Out:
# 78.5
# 31.400000000000002

# %% [markdown]
# What is Instantiation in terms of OOP terminology?
#
# ANS) Instantiation is the creation of an object is an object oriented programming language.

# %% [markdown]
# What is used to check whether an object o is an instance of class A?
